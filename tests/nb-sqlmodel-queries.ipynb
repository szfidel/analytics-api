# %%
import sys
from pathlib import Path

# %%
import os
from pathlib import Path
from pprint import pprint

# %%
src_path = Path("../src").resolve()
sys.path.append(str(src_path))

# %%
from sqlmodel import Session, select
from timescaledb.hyperfunctions import time_bucket
from pprint import pprint

# %%
from api.db.session import engine
from api.events.models import EventModel

# %% [markdown]
# # Run queries with sqlmodel session
# - Using sqlmodel object queries
# - query.compile() gives raw sql query.

# %%
with Session(engine) as session:
    query = select(EventModel).order_by(EventModel.user_id.asc()).limit(10)
    compiled_query = query.compile(compile_kwargs={"literal_binds": True})
    print(compiled_query)
    print("")
    print(str(query))
    results = session.exec(query).fetchall()
    print("")
    pprint(results)
# Out:
# SELECT events.id, events.time, events.user_id, events.agent_id, events.signal_type, events.emotional_tone, events.drift_score, events.escalate_flag, events.payload, events.relationship_context, events.diagnostic_notes
# FROM events ORDER BY events.user_id ASC
#  LIMIT 10
#
# SELECT events.id, events.time, events.user_id, events.agent_id, events.signal_type, events.emotional_tone, events.drift_score, events.escalate_flag, events.payload, events.relationship_context, events.diagnostic_notes
# FROM events ORDER BY events.user_id ASC
#  LIMIT :param_1
#
# [EventModel(id=1, agent_id='Axis', emotional_tone=0.72, escalate_flag=0, relationship_context='customer_support', time=datetime.datetime(2025, 11, 7, 2, 59, 2, 582611, tzinfo=datetime.timezone.utc), user_id='u_123', signal_type='relational', drift_score=0.15, payload='{"language": "en-US", "confidence": 0.94, "transcript": "I\'m feeling a bit uncertain about this decision."}', diagnostic_notes='User expressed mild hesitation; tone within normal range.'),
#  EventModel(id=4, agent_id='Nova', emotional_tone=0.88, escalate_flag=0, relationship_context='customer_support', time=datetime.datetime(2025, 11, 7, 3, 7, 41, 208196, tzinfo=datetime.timezone.utc), user_id='u_123', signal_type='behavioral', drift_score=0.39, payload=None, diagnostic_notes='Auto-generated event for testing.'),
#  EventModel(id=10, agent_id='Orion', emotional_tone=0.81, escalate_flag=0, relationship_context='customer_support', time=datetime.datetime(2025, 11, 7, 18, 11, 25, 398343, tzinfo=datetime.timezone.utc), user_id='u_123', signal_type='behavioral', drift_score=0.25, payload=None, diagnostic_notes='Auto-generated event for testing.'),
#  EventModel(id=2, agent_id='Nova', emotional_tone=0.39, escalate_flag=1, relationship_context='customer_support', time=datetime.datetime(2025, 11, 7, 3, 7, 41, 167261, tzinfo=datetime.timezone.utc), user_id='u_456', signal_type='relational', drift_score=0.26, payload=None, diagnostic_notes='Auto-generated event for testing.'),
#  EventModel(id=3, agent_id='Nova', emotional_tone=0.68, escalate_flag=0, relationship_context='customer_support', time=datetime.datetime(2025, 11, 7, 3, 7, 41, 200508, tzinfo=datetime.timezone.utc), user_id='u_456', signal_type='relational', drift_score=0.09, payload=None, diagnostic_notes='Auto-generated event for testing.'),
#  EventModel(id=5, agent_id='Axis', emotional_tone=0.77, escalate_flag=0, relationship_context='customer_support', time=datetime.datetime(2025, 11, 7, 3, 7, 41, 214583, tzinfo=datetime.timezone.utc), user_id='u_789', signal_type='relational', drift_score=0.12, payload=None, diagnostic_notes='Auto-generated event for testing.'),
#  EventModel(id=6, agent_id='Axis', emotional_tone=0.65, escalate_flag=0, relationship_context='customer_support', time=datetime.datetime(2025, 11, 7, 3, 7, 41, 220339, tzinfo=datetime.timezone.utc), user_id='u_789', signal_type='emotional', drift_score=0.35, payload=None, diagnostic_notes='Auto-generated event for testing.'),
#  EventModel(id=7, agent_id='Nova', emotional_tone=0.5, escalate_flag=0, relationship_context='customer_support', time=datetime.datetime(2025, 11, 7, 18, 11, 25, 356119, tzinfo=datetime.timezone.utc), user_id='u_789', signal_type='emotional', drift_score=0.07, payload=None, diagnostic_notes='Auto-generated event for testing.'),
#  EventModel(id=8, agent_id='Orion', emotional_tone=0.42, escalate_flag=0, relationship_context='customer_support', time=datetime.datetime(2025, 11, 7, 18, 11, 25, 381971, tzinfo=datetime.timezone.utc), user_id='u_789', signal_type='relational', drift_score=0.18, payload=None, diagnostic_notes='Auto-generated event for testing.'),
#  EventModel(id=9, agent_id='Nova', emotional_tone=0.25, escalate_flag=1, relationship_context='customer_support', time=datetime.datetime(2025, 11, 7, 18, 11, 25, 390335, tzinfo=datetime.timezone.utc), user_id='u_789', signal_type='behavioral', drift_score=0.16, payload=None, diagnostic_notes='Auto-generated event for testing.')]

# %%
from sqlalchemy import func

# %%
with Session(engine) as session:
    bucket = time_bucket("1 day", EventModel.time)
    signal_types = ["relational", "emotional", "behavioral"]
    query = (
        select(
            bucket.label("bucket"),
            EventModel.signal_type,
            EventModel.agent_id,
            func.avg(EventModel.emotional_tone).label("avg_emotional_tone"),
            func.avg(EventModel.drift_score).label("avg_drift_score"),
            func.count().label("total_count"),
        )
        .where(EventModel.signal_type.in_(signal_types))
        .group_by(
            bucket,
            EventModel.signal_type,
            EventModel.agent_id,
        )
        .order_by(
            bucket,
            EventModel.signal_type,
            EventModel.agent_id,
        )
    )

    compiled_query = query.compile(compile_kwargs={"literal_binds": True})
    print(compiled_query)
    results = session.exec(query).fetchall()
    pprint(results)
# Out:
# SELECT time_bucket('1 day'::interval, events.time) AS bucket, events.signal_type, events.agent_id, avg(events.emotional_tone) AS avg_emotional_tone, avg(events.drift_score) AS avg_drift_score, count(*) AS total_count
# FROM events
# WHERE events.signal_type IN ('relational', 'emotional', 'behavioral') GROUP BY time_bucket('1 day'::interval, events.time), events.signal_type, events.agent_id ORDER BY time_bucket('1 day'::interval, events.time), events.signal_type, events.agent_id
# [(datetime.datetime(2025, 11, 7, 0, 0, tzinfo=datetime.timezone.utc), 'behavioral', 'Nova', 0.565, 0.275, 2),
#  (datetime.datetime(2025, 11, 7, 0, 0, tzinfo=datetime.timezone.utc), 'behavioral', 'Orion', 0.81, 0.25, 1),
#  (datetime.datetime(2025, 11, 7, 0, 0, tzinfo=datetime.timezone.utc), 'emotional', 'Axis', 0.65, 0.35, 1),
#  (datetime.datetime(2025, 11, 7, 0, 0, tzinfo=datetime.timezone.utc), 'emotional', 'Nova', 0.5, 0.07, 1),
#  (datetime.datetime(2025, 11, 7, 0, 0, tzinfo=datetime.timezone.utc), 'relational', 'Axis', 0.745, 0.135, 2),
#  (datetime.datetime(2025, 11, 7, 0, 0, tzinfo=datetime.timezone.utc), 'relational', 'Nova', 0.535, 0.175, 2),
#  (datetime.datetime(2025, 11, 7, 0, 0, tzinfo=datetime.timezone.utc), 'relational', 'Orion', 0.37, 0.235, 2),
#  (datetime.datetime(2025, 11, 14, 0, 0, tzinfo=datetime.timezone.utc), 'relational', 'Axis', 0.7200000000000001, 0.15, 3)]

# %% [markdown]
# # Insert into database with Raw SQL
# Using text, exec and commit.

# %%
from sqlmodel import text

# %%
with Session(engine) as session:
    query = text("""INSERT INTO events (
    time,
    user_id,
    agent_id,
    signal_type,
    emotional_tone,
    drift_score,
    escalate_flag,
    payload,
    relationship_context,
    diagnostic_notes
)
VALUES (
    NOW(),
    'u_123',
    'Axis',
    'relational',
    0.72,
    0.15,
    0,
    '{
        "transcript": "I''m feeling a bit uncertain about this decision.",
        "confidence": 0.94,
        "language": "en-US"
    }'::jsonb,
    'customer_support',
    'User expressed mild hesitation; tone within normal range.'
)""")
    session.exec(query)
    session.commit()
